# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Fuel_Datasheet.csv')
df
# Out:
#           Date       Day  Petrol Price  Diesel Price  Dollar Value  \
# 0    16-Jun-17    Friday         68.02         57.41       64.3930
# 1    17-Jun-17  Saturday         67.76         57.23       64.4388
# 2    18-Jun-17    Sunday         67.42         57.03       64.3984
# 3    19-Jun-17    Monday         67.14         56.89       64.4906
# 4    20-Jun-17   Tuesday         67.04         56.85       64.6418
# ..         ...       ...           ...           ...           ...
# 448  07-Sep-18    Friday         83.13         76.17       72.1035
# 449  08-Sep-18  Saturday         83.54         76.64       72.1033
# 450  09-Sep-18    Sunday         83.66         76.75       72.1041
# 451  10-Sep-18    Monday         83.91         76.98       72.5755
# 452  11-Sep-18   Tuesday         84.05         77.13       72.6584
#
#      Oil Barrel  Barrel Cost   Moving Avg
# 0         44.74  2880.942820     0.000000
# 1         44.58  2872.681704     0.000000
# ...

# %%
df.head()
# Out:
#         Date       Day  Petrol Price  Diesel Price  Dollar Value  Oil Barrel  \
# 0  16-Jun-17    Friday         68.02         57.41       64.3930       44.74
# 1  17-Jun-17  Saturday         67.76         57.23       64.4388       44.58
# 2  18-Jun-17    Sunday         67.42         57.03       64.3984       44.39
# 3  19-Jun-17    Monday         67.14         56.89       64.4906       44.20
# 4  20-Jun-17   Tuesday         67.04         56.85       64.6418       43.23
#
#    Barrel Cost   Moving Avg
# 0  2880.942820     0.000000
# 1  2872.681704     0.000000
# 2  2858.644976     0.000000
# 3  2850.484520  2865.688505
# 4  2794.465014  2844.069054

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          453 non-null    object
#  1   Day           453 non-null    object
#  2   Petrol Price  453 non-null    float64
#  3   Diesel Price  453 non-null    float64
#  4   Dollar Value  453 non-null    float64
#  5   Oil Barrel    453 non-null    float64
#  6   Barrel Cost   453 non-null    float64
#  7   Moving Avg    453 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 28.4+ KB

# %%
df.isnull().sum()
# Out:
# Date            0
# Day             0
# Petrol Price    0
# Diesel Price    0
# Dollar Value    0
# Oil Barrel      0
# Barrel Cost     0
# Moving Avg      0
# dtype: int64

# %%
df[['Petrol Price','Diesel Price','Dollar Value','Oil Barrel','Barrel Cost','Moving Avg']]=df[['Petrol Price','Diesel Price','Dollar Value','Oil Barrel','Barrel Cost','Moving Avg']].replace(0,np.nan)

# %%
df.isnull().sum()
# Out:
# Date            0
# Day             0
# Petrol Price    0
# Diesel Price    0
# Dollar Value    0
# Oil Barrel      0
# Barrel Cost     0
# Moving Avg      3
# dtype: int64

# %%
df['Moving Avg'].fillna(df['Moving Avg'].mean(),inplace=True)
# Out:
# /tmp/ipython-input-96-386306875.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Moving Avg'].fillna(df['Moving Avg'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Date            0
# Day             0
# Petrol Price    0
# Diesel Price    0
# Dollar Value    0
# Oil Barrel      0
# Barrel Cost     0
# Moving Avg      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#         Date       Day  Petrol Price  Diesel Price  Dollar Value  Oil Barrel  \
# 0  16-Jun-17    Friday         68.02         57.41       64.3930       44.74
# 1  17-Jun-17  Saturday         67.76         57.23       64.4388       44.58
# 2  18-Jun-17    Sunday         67.42         57.03       64.3984       44.39
# 3  19-Jun-17    Monday         67.14         56.89       64.4906       44.20
# 4  20-Jun-17   Tuesday         67.04         56.85       64.6418       43.23
#
#    Barrel Cost   Moving Avg
# 0  2880.942820  3948.038868
# 1  2872.681704  3948.038868
# 2  2858.644976  3948.038868
# 3  2850.484520  2865.688505
# 4  2794.465014  2844.069054

# %% [markdown]
# # Visulaisation

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Petrol Price'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Diesel Price'])
plt.show()
# Out:
# /tmp/ipython-input-101-2424049930.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Diesel Price'])

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Day',y='Moving Avg',data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='Day',y='Moving Avg',data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Day',y='Moving Avg',data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='Day',y='Dollar Value',data=df)
plt.show()

# %%
df2=df[['Petrol Price','Diesel Price','Dollar Value','Oil Barrel','Barrel Cost','Moving Avg']]

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df2.corr(),annot=True)
plt.show()

# %% [markdown]
# # Filtering

# %%
df.head(10)
# Out:
#         Date        Day  Petrol Price  Diesel Price  Dollar Value  Oil Barrel  \
# 0  16-Jun-17     Friday         68.02         57.41       64.3930       44.74
# 1  17-Jun-17   Saturday         67.76         57.23       64.4388       44.58
# 2  18-Jun-17     Sunday         67.42         57.03       64.3984       44.39
# 3  19-Jun-17     Monday         67.14         56.89       64.4906       44.20
# 4  20-Jun-17    Tuesday         67.04         56.85       64.6418       43.23
# 5  21-Jun-17  Wednesday         67.04         56.84       64.5522       42.53
# 6  22-Jun-17   Thursday         66.93         56.82       64.5950       42.74
# 7  23-Jun-17     Friday         66.70         56.73       64.4744       43.01
# 8  24-Jun-17   Saturday         66.45         56.63       64.4943       43.13
# 9  25-Jun-17     Sunday         66.15         56.47       64.4947       43.26
#
#    Barrel Cost   Moving Avg
# 0  2880.942820  3948.038868
# 1  2872.681704  3948.038868
# ...

# %% [markdown]
# # petrol price Train/Test

# %%
x=df[['Oil Barrel']]
y=df['Petrol Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(regression.score(x_test,y_test))
l_pred=regression.predict(x_test)
# Out:
# 0.8032777432357824

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR
regression_s=SVR()
regression_s.fit(x_train,y_train)
# Out:
# SVR()

# %%
print(regression_s.score(x_test,y_test))
s_pred=regression_s.predict(x_test)
# Out:
# 0.8443291169554699

# %% [markdown]
# # Decition tree

# %%
from sklearn.tree import DecisionTreeRegressor
regression_d=DecisionTreeRegressor()
regression_d.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
print(regression_d.score(x_test,y_test))
d_pred=regression_d.predict(x_test)
# Out:
# 0.7747425140197053

# %% [markdown]
# # random forest

# %%
from sklearn.ensemble import RandomForestRegressor
regression_r=RandomForestRegressor()
regression_r.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
print(regression_r.score(x_test,y_test))
r_pred=regression_r.predict(x_test)
# Out:
# 0.8284655858635481

# %% [markdown]
# # petrol price save model

# %%
import pickle
filename='petrol_model.pkl'
pickle.dump(regression_s,open(filename,'wb'))

# %% [markdown]
# # Diesel price trian/test

# %%
x=df[['Oil Barrel']]
y=df['Diesel Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
D_regression = LinearRegression()
D_regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(regression.score(x_test,y_test))
D_l_pred=D_regression.predict(x_test)
# Out:
# -1.2885993639748436

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR
D_regression_s=SVR()
D_regression_s.fit(x_train,y_train)
# Out:
# SVR()

# %%
print(regression_s.score(x_test,y_test))
D_s_pred=D_regression_s.predict(x_test)
# Out:
# -1.2555040809206202

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
D_regression_d=DecisionTreeRegressor()
D_regression_d.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
print(regression_d.score(x_test,y_test))
D_d_pred=D_regression_d.predict(x_test)
# Out:
# -1.2801128262252734

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
D_regression_r=RandomForestRegressor()
D_regression_r.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
print(regression_r.score(x_test,y_test))
D_r_pred=D_regression_r.predict(x_test)
# Out:
# -1.2989597840969132

# %% [markdown]
# # Diesel price save model

# %%
import pickle
filename='diesel_model.pkl'
pickle.dump(D_regression_s,open(filename,'wb'))
